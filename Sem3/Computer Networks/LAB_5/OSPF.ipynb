# %% [markdown]
# # Introduction to OSPF
# <i>Adapted for use with FABRIC from [OSPF](https://www.cs.unc.edu/Research/geni/geniEdu/06-Ospf.html)</i>
#
# In this tutorial you will experiment with the OSPF routing protocol.
#
# <b> Prerequisites
#
# * You need to have your FABRIC bastion host key pair set up to do this tutorial. If you have not already set this up, follow steps 1-5 at https://github.com/fabric-testbed/teaching-materials/blob/main/Getting%20Started.md#section-1-get-started.
# * You are comfortable using ssh and executing basic commands using a UNIX shell. [Tips about how to login to hosts.](https://github.com/fabric-testbed/teaching-materials/blob/main/Getting%20Started.md)
#
# <br><img src="https://github.com/fabric-testbed/teaching-materials/blob/main/assignments/OSPF/figures/OSPFTop.png?raw=true"><br>
# OSPF stands for Open Shortest Path First and is currently the most widely used interior gateway protocol in the world. OSPF is a dynamic routing protocol, meaning changes are accounted for automatically. Hello messages are used to discover neighbors and find breaks. By default, hello messages are sent by OSPF routers every 10 seconds on point to point segments.
# <br><br>Each OSPF router maintains a Link State Database (LSDB) containing Link State Advertisements (LSAs). Newly discovered neighbors exchange their LSDBs with Database Description (DDs) messages.
# <br><br>OSPF uses Router Dead Intervals, the maximum time a router may be "silent" before being declared "down". OSPF uses Djikstra's Shortest path algorithm to compute routes.
# <br><br>This is the second step in this assignment. To go to the previous step go to slice creation notebook or click [Here](./CreateSlice.ipynb)

# %% [markdown]
# ## 1. Retrieve Slice
# Create the slice at the [Create Slice Notebook](./CreateSlice.ipynb) and import it here.
# #### Import the Fabric API

# %%
# Load Fablib and Node Information
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager
fablib = fablib_manager(
    token_location="id_token.json",          
    project_name="Computer_Networks" 
)                    
fablib.show_config()
import json
import traceback

slice_name = "LAB5_OSPF_VISESH"
slice = fablib.get_slice(slice_name)
slice.list_nodes()
# Out:
# User: vbent01@jaguar.tamu.edu bastion key is valid!
# Configuration is valid
# <style type="text/css">
# #T_1ac5b tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_1ac5b tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_1ac5b caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_1ac5b_row0_col0, #T_1ac5b_row0_col1, #T_1ac5b_row1_col0, #T_1ac5b_row1_col1, #T_1ac5b_row2_col0, #T_1ac5b_row2_col1, #T_1ac5b_row3_col0, #T_1ac5b_row3_col1, #T_1ac5b_row4_col0, #T_1ac5b_row4_col1, #T_1ac5b_row5_col0, #T_1ac5b_row5_col1, #T_1ac5b_row6_col0, #T_1ac5b_row6_col1, #T_1ac5b_row7_col0, #T_1ac5b_row7_col1, #T_1ac5b_row8_col0, #T_1ac5b_row8_col1, #T_1ac5b_row9_col0, #T_1ac5b_row9_col1, #T_1ac5b_row10_col0, #T_1ac5b_row10_col1, #T_1ac5b_row11_col0, #T_1ac5b_row11_col1, #T_1ac5b_row12_col0, #T_1ac5b_row12_col1, #T_1ac5b_row13_col0, #T_1ac5b_row13_col1, #T_1ac5b_row14_col0, #T_1ac5b_row14_col1, #T_1ac5b_row15_col0, #T_1ac5b_row15_col1, #T_1ac5b_row16_col0, #T_1ac5b_row16_col1, #T_1ac5b_row17_col0, #T_1ac5b_row17_col1, #T_1ac5b_row18_col0, #T_1ac5b_row18_col1, #T_1ac5b_row19_col0, #T_1ac5b_row19_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_1ac5b">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1ac5b_row0_col0" class="data row0 col0" >Version</td>
#       <td id="T_1ac5b_row0_col1" class="data row0 col1" >1.9.3</td>
#     </tr>
#     <tr>
#       <td id="T_1ac5b_row1_col0" class="data row1 col0" >Project Name</td>
#       <td id="T_1ac5b_row1_col1" class="data row1 col1" >Computer_Networks</td>
#     </tr>
#     <tr>
#       <td id="T_1ac5b_row2_col0" class="data row2 col0" >Token File</td>
#       <td id="T_1ac5b_row2_col1" class="data row2 col1" >id_token.json</td>
#     </tr>
#     <tr>
#       <td id="T_1ac5b_row3_col0" class="data row3 col0" >Log Level</td>
#       <td id="T_1ac5b_row3_col1" class="data row3 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_1ac5b_row4_col0" class="data row4 col0" >Log File</td>
#       <td id="T_1ac5b_row4_col1" class="data row4 col1" >/tmp/fablib/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_1ac5b_row5_col0" class="data row5 col0" >Data directory</td>
#       <td id="T_1ac5b_row5_col1" class="data row5 col1" >/tmp/fablib</td>
#     </tr>
#     <tr>
#       <td id="T_1ac5b_row6_col0" class="data row6 col0" >Orchestrator</td>
#       <td id="T_1ac5b_row6_col1" class="data row6 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_1ac5b_row7_col0" class="data row7 col0" >Credential Manager</td>
#       <td id="T_1ac5b_row7_col1" class="data row7 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_1ac5b_row8_col0" class="data row8 col0" >Core API</td>
#       <td id="T_1ac5b_row8_col1" class="data row8 col1" >uis.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_1ac5b_row9_col0" class="data row9 col0" >Artifact Manager</td>
#       <td id="T_1ac5b_row9_col1" class="data row9 col1" >artifacts.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_1ac5b_row10_col0" class="data row10 col0" >Bastion Host</td>
#       <td id="T_1ac5b_row10_col1" class="data row10 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_1ac5b_row11_col0" class="data row11 col0" >Bastion Private Key File</td>
#       <td id="T_1ac5b_row11_col1" class="data row11 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_1ac5b_row12_col0" class="data row12 col0" >Slice Public Key File</td>
#       <td id="T_1ac5b_row12_col1" class="data row12 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_1ac5b_row13_col0" class="data row13 col0" >Slice Private Key File</td>
#       <td id="T_1ac5b_row13_col1" class="data row13 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_1ac5b_row14_col0" class="data row14 col0" >Sites to avoid</td>
#       <td id="T_1ac5b_row14_col1" class="data row14 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_1ac5b_row15_col0" class="data row15 col0" >SSH Command Line</td>
#       <td id="T_1ac5b_row15_col1" class="data row15 col1" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#     </tr>
#     <tr>
#       <td id="T_1ac5b_row16_col0" class="data row16 col0" >Bastion SSH Config File</td>
#       <td id="T_1ac5b_row16_col1" class="data row16 col1" >/home/fabric/work/fabric_config/ssh_config</td>
#     </tr>
#     <tr>
#       <td id="T_1ac5b_row17_col0" class="data row17 col0" >Fabric Meta Data Release Tag</td>
#       <td id="T_1ac5b_row17_col1" class="data row17 col1" >main</td>
#     </tr>
#     <tr>
#       <td id="T_1ac5b_row18_col0" class="data row18 col0" >Project ID</td>
#       <td id="T_1ac5b_row18_col1" class="data row18 col1" >a70de2f5-9e12-4b6b-b412-0ae1a2c553b0</td>
#     </tr>
#     <tr>
#       <td id="T_1ac5b_row19_col0" class="data row19 col0" >Bastion Username</td>
#       <td id="T_1ac5b_row19_col1" class="data row19 col1" >vbent01_0000366457</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_96169 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_96169 th {
#   text-align: left;
# }
# #T_96169 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_96169 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_96169 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_96169_row0_col0, #T_96169_row0_col1, #T_96169_row0_col2, #T_96169_row0_col3, #T_96169_row0_col4, #T_96169_row0_col5, #T_96169_row0_col6, #T_96169_row0_col7, #T_96169_row0_col8, #T_96169_row0_col9, #T_96169_row0_col10, #T_96169_row0_col11, #T_96169_row0_col12, #T_96169_row0_col13, #T_96169_row0_col14, #T_96169_row0_col15, #T_96169_row1_col0, #T_96169_row1_col1, #T_96169_row1_col2, #T_96169_row1_col3, #T_96169_row1_col4, #T_96169_row1_col5, #T_96169_row1_col6, #T_96169_row1_col7, #T_96169_row1_col8, #T_96169_row1_col9, #T_96169_row1_col10, #T_96169_row1_col11, #T_96169_row1_col12, #T_96169_row1_col13, #T_96169_row1_col14, #T_96169_row1_col15, #T_96169_row2_col0, #T_96169_row2_col1, #T_96169_row2_col2, #T_96169_row2_col3, #T_96169_row2_col4, #T_96169_row2_col5, #T_96169_row2_col6, #T_96169_row2_col7, #T_96169_row2_col8, #T_96169_row2_col9, #T_96169_row2_col10, #T_96169_row2_col11, #T_96169_row2_col12, #T_96169_row2_col13, #T_96169_row2_col14, #T_96169_row2_col15, #T_96169_row3_col0, #T_96169_row3_col1, #T_96169_row3_col2, #T_96169_row3_col3, #T_96169_row3_col4, #T_96169_row3_col5, #T_96169_row3_col6, #T_96169_row3_col7, #T_96169_row3_col8, #T_96169_row3_col9, #T_96169_row3_col10, #T_96169_row3_col11, #T_96169_row3_col12, #T_96169_row3_col13, #T_96169_row3_col14, #T_96169_row3_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_96169">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_96169_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_96169_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_96169_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_96169_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_96169_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_96169_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_96169_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_96169_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_96169_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_96169_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_96169_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_96169_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_96169_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_96169_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_96169_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_96169_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_96169_row0_col0" class="data row0 col0" >3510d886-d429-48df-a8ee-ea5af7061085</td>
#       <td id="T_96169_row0_col1" class="data row0 col1" >ND_A</td>
#       <td id="T_96169_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_96169_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_96169_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_96169_row0_col5" class="data row0 col5" >default_ubuntu_20</td>
#       <td id="T_96169_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_96169_row0_col7" class="data row0 col7" >eduky-w8.fabric-testbed.net</td>
#       <td id="T_96169_row0_col8" class="data row0 col8" >EDUKY</td>
#       <td id="T_96169_row0_col9" class="data row0 col9" >ubuntu</td>
#       <td id="T_96169_row0_col10" class="data row0 col10" >2610:1e0:1700:206:f816:3eff:fe91:b948</td>
#       <td id="T_96169_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_96169_row0_col12" class="data row0 col12" ></td>
#       <td id="T_96169_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2610:1e0:1700:206:f816:3eff:fe91:b948</td>
#       <td id="T_96169_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_96169_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_96169_row1_col0" class="data row1 col0" >eab678c2-21df-4f41-961c-02c3d4c89571</td>
#       <td id="T_96169_row1_col1" class="data row1 col1" >ND_B</td>
#       <td id="T_96169_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_96169_row1_col3" class="data row1 col3" >8</td>
#       <td id="T_96169_row1_col4" class="data row1 col4" >10</td>
#       <td id="T_96169_row1_col5" class="data row1 col5" >default_ubuntu_20</td>
#       <td id="T_96169_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_96169_row1_col7" class="data row1 col7" >eduky-w3.fabric-testbed.net</td>
#       <td id="T_96169_row1_col8" class="data row1 col8" >EDUKY</td>
#       <td id="T_96169_row1_col9" class="data row1 col9" >ubuntu</td>
#       <td id="T_96169_row1_col10" class="data row1 col10" >2610:1e0:1700:206:f816:3eff:fe0f:7702</td>
#       <td id="T_96169_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_96169_row1_col12" class="data row1 col12" ></td>
#       <td id="T_96169_row1_col13" class="data row1 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2610:1e0:1700:206:f816:3eff:fe0f:7702</td>
#       <td id="T_96169_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_96169_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_96169_row2_col0" class="data row2 col0" >a6a17281-f463-4044-9f49-58cf9ffbd0ce</td>
#       <td id="T_96169_row2_col1" class="data row2 col1" >ND_C</td>
#       <td id="T_96169_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_96169_row2_col3" class="data row2 col3" >8</td>
#       <td id="T_96169_row2_col4" class="data row2 col4" >10</td>
#       <td id="T_96169_row2_col5" class="data row2 col5" >default_ubuntu_20</td>
#       <td id="T_96169_row2_col6" class="data row2 col6" >qcow2</td>
#       <td id="T_96169_row2_col7" class="data row2 col7" >eduky-w4.fabric-testbed.net</td>
#       <td id="T_96169_row2_col8" class="data row2 col8" >EDUKY</td>
#       <td id="T_96169_row2_col9" class="data row2 col9" >ubuntu</td>
#       <td id="T_96169_row2_col10" class="data row2 col10" >2610:1e0:1700:206:f816:3eff:fe44:1d38</td>
#       <td id="T_96169_row2_col11" class="data row2 col11" >Active</td>
#       <td id="T_96169_row2_col12" class="data row2 col12" ></td>
#       <td id="T_96169_row2_col13" class="data row2 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2610:1e0:1700:206:f816:3eff:fe44:1d38</td>
#       <td id="T_96169_row2_col14" class="data row2 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_96169_row2_col15" class="data row2 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_96169_row3_col0" class="data row3 col0" >9faa45de-3c97-4f73-a94c-cb49958c4d40</td>
#       <td id="T_96169_row3_col1" class="data row3 col1" >ND_D</td>
#       <td id="T_96169_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_96169_row3_col3" class="data row3 col3" >8</td>
#       <td id="T_96169_row3_col4" class="data row3 col4" >10</td>
#       <td id="T_96169_row3_col5" class="data row3 col5" >default_ubuntu_20</td>
#       <td id="T_96169_row3_col6" class="data row3 col6" >qcow2</td>
#       <td id="T_96169_row3_col7" class="data row3 c
# <style type="text/css">
# #T_96169 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_96169 th {
#   text-align: left;
# }
# #T_96169 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_96169 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_96169 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_96169_row0_col0, #T_96169_row0_col1, #T_96169_row0_col2, #T_96169_row0_col3, #T_96169_row0_col4, #T_96169_row0_col5, #T_96169_row0_col6, #T_96169_row0_col7, #T_96169_row0_col8, #T_96169_row0_col9, #T_96169_row0_col10, #T_96169_row0_col11, #T_96169_row0_col12, #T_96169_row0_col13, #T_96169_row0_col14, #T_96169_row0_col15, #T_96169_row1_col0, #T_96169_row1_col1, #T_96169_row1_col2, #T_96169_row1_col3, #T_96169_row1_col4, #T_96169_row1_col5, #T_96169_row1_col6, #T_96169_row1_col7, #T_96169_row1_col8, #T_96169_row1_col9, #T_96169_row1_col10, #T_96169_row1_col11, #T_96169_row1_col12, #T_96169_row1_col13, #T_96169_row1_col14, #T_96169_row1_col15, #T_96169_row2_col0, #T_96169_row2_col1, #T_96169_row2_col2, #T_96169_row2_col3, #T_96169_row2_col4, #T_96169_row2_col5, #T_96169_row2_col6, #T_96169_row2_col7, #T_96169_row2_col8, #T_96169_row2_col9, #T_96169_row2_col10, #T_96169_row2_col11, #T_96169_row2_col12, #T_96169_row2_col13, #T_96169_row2_col14, #T_96169_row2_col15, #T_96169_row3_col0, #T_96169_row3_col1, #T_96169_row3_col2, #T_96169_row3_col3, #T_96169_row3_col4, #T_96169_row3_col5, #T_96169_row3_col6, #T_96169_row3_col7, #T_96169_row3_col8, #T_96169_row3_col9, #T_96169_row3_col10, #T_96169_row3_col11, #T_96169_row3_col12, #T_96169_row3_col13, #T_96169_row3_col14, #T_96169_row3_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_96169">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_96169_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_96169_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_96169_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_96169_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_96169_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_96169_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_96169_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_96169_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_96169_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_96169_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_96169_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_96169_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_96169_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_96169_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_96169_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_96169_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_96169_row0_col0" class="data row0 col0" >3510d886-d429-48df-a8ee-ea5af7061085</td>
#       <td id="T_96169_row0_col1" class="data row0 col1" >ND_A</td>
#       <td id="T_96169_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_96169_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_96169_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_96169_row0_col5" class="data row0 col5" >default_ubuntu_20</td>
#       <td id="T_96169_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_96169_row0_col7" class="data row0 col7" >eduky-w8.fabric-testbed.net</td>
#       <td id="T_96169_row0_col8" class="data row0 col8" >EDUKY</td>
#       <td id="T_96169_row0_col9" class="data row0 col9" >ubuntu</td>
#       <td id="T_96169_row0_col10" class="data row0 col10" >2610:1e0:1700:206:f816:3eff:fe91:b948</td>
#       <td id="T_96169_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_96169_row0_col12" class="data row0 col12" ></td>
#       <td id="T_96169_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2610:1e0:1700:206:f816:3eff:fe91:b948</td>
#       <td id="T_96169_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_96169_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_96169_row1_col0" class="data row1 col0" >eab678c2-21df-4f41-961c-02c3d4c89571</td>
#       <td id="T_96169_row1_col1" class="data row1 col1" >ND_B</td>
#       <td id="T_96169_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_96169_row1_col3" class="data row1 col3" >8</td>
#       <td id="T_96169_row1_col4" class="data row1 col4" >10</td>
#       <td id="T_96169_row1_col5" class="data row1 col5" >default_ubuntu_20</td>
#       <td id="T_96169_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_96169_row1_col7" class="data row1 col7" >eduky-w3.fabric-testbed.net</td>
#       <td id="T_96169_row1_col8" class="data row1 col8" >EDUKY</td>
#       <td id="T_96169_row1_col9" class="data row1 col9" >ubuntu</td>
#       <td id="T_96169_row1_col10" class="data row1 col10" >2610:1e0:1700:206:f816:3eff:fe0f:7702</td>
#       <td id="T_96169_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_96169_row1_col12" class="data row1 col12" ></td>
#       <td id="T_96169_row1_col13" class="data row1 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2610:1e0:1700:206:f816:3eff:fe0f:7702</td>
#       <td id="T_96169_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_96169_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_96169_row2_col0" class="data row2 col0" >a6a17281-f463-4044-9f49-58cf9ffbd0ce</td>
#       <td id="T_96169_row2_col1" class="data row2 col1" >ND_C</td>
#       <td id="T_96169_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_96169_row2_col3" class="data row2 col3" >8</td>
#       <td id="T_96169_row2_col4" class="data row2 col4" >10</td>
#       <td id="T_96169_row2_col5" class="data row2 col5" >default_ubuntu_20</td>
#       <td id="T_96169_row2_col6" class="data row2 col6" >qcow2</td>
#       <td id="T_96169_row2_col7" class="data row2 col7" >eduky-w4.fabric-testbed.net</td>
#       <td id="T_96169_row2_col8" class="data row2 col8" >EDUKY</td>
#       <td id="T_96169_row2_col9" class="data row2 col9" >ubuntu</td>
#       <td id="T_96169_row2_col10" class="data row2 col10" >2610:1e0:1700:206:f816:3eff:fe44:1d38</td>
#       <td id="T_96169_row2_col11" class="data row2 col11" >Active</td>
#       <td id="T_96169_row2_col12" class="data row2 col12" ></td>
#       <td id="T_96169_row2_col13" class="data row2 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2610:1e0:1700:206:f816:3eff:fe44:1d38</td>
#       <td id="T_96169_row2_col14" class="data row2 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_96169_row2_col15" class="data row2 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_96169_row3_col0" class="data row3 col0" >9faa45de-3c97-4f73-a94c-cb49958c4d40</td>
#       <td id="T_96169_row3_col1" class="data row3 col1" >ND_D</td>
#       <td id="T_96169_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_96169_row3_col3" class="data row3 col3" >8</td>
#       <td id="T_96169_row3_col4" class="data row3 col4" >10</td>
#       <td id="T_96169_row3_col5" class="data row3 col5" >default_ubuntu_20</td>
#       <td id="T_96169_row3_col6" class="data row3 col6" >qcow2</td>
#       <td id="T_96169_row3_col7" class="data row3 c

# %% [markdown]
# ## 2. Guided Experiment
#
# <br><img src="https://github.com/fabric-testbed/teaching-materials/blob/main/assignments/OSPF/figures/ospf.png?raw=true"><br>
#
# ### 2.1 Router Interface
# 1. Login to each node
# 2. Open the Quagga shell
# Quagga provides an integrated user interface shell called vtysh, a cisco-like CLI, connecting to the underlying daemons (zebra and ospfd). <br>Open the shell on each node by typing:
# <br>```sudo vtysh```
# 3. Look at the OSPF neighbors for a node by typing the following into a vtysh console:
# <br>```show ip ospf neighbor```
# <br>The output shows the status of neighbors including details of the connections, such as the Dead time, which indicates a countdown to refresh the connection.
#
# 4. The routing table for a node can be seen by typing the following into a vtysh console:
# <br>```show ip ospf route```
# <br>This table shows how packets would be forwarded from the source to a given available destination.
# 5. Exiting the console can be done by executing:
# <br>```exit```
#
#
# ### 2.2 Dead Link
# 1. Login to a node
# 2. Show available interfaces with:
# <br>```ip addr```
# 3. Take down one of the links (enp7s0 or enp87s0). Keep in mind the IP address associated:
# <br>```sudo ip link set dev <interface> down```
#
# 4. Quickly switch back to vtysh shell and reissue:
# <br>```show ip ospf neighbor```
#
# 5. Reissue the command multiple times and watch the Dead Time count down until the neighbor is removed from the table. The other link will also count down but resets when receiving a hello message.
#
# 6. Exit the console and bring the interface back up by typing:
# <br>```sudo ip link set dev <interface> up```
# 7. List the OSPF neighbors once more to see the link listed.
#
# ### 2.3 Route Change
# <br><img src="https://github.com/fabric-testbed/teaching-materials/blob/main/assignments/OSPF/figures/deadLink.png?raw=true"><br>
# 1. Login to node 'A'
# 2. Run the following command:
# <br>```traceroute 10.1.2.2```
# <br>Traceroute will determine the route that the packets are traveling through the network. Running the command on node A will show packets traveling through 10.1.1.2 (node B) to 10.1.2.2 (node C).
# 3. Take down the interface to node B (enp8s0 or enp7s0):
# <br>```sudo ip link set dev <interface> down```
#
# 4. Run traceroute again:
# <br>```traceroute 10.1.2.2```
# <br>The output should now show traffic going through 10.1.4.1 (node D).
# 5. Bring the route to node B back up:
# <br>```sudo ip link set dev <interface> up```
# 6. Repeatedly run traceroute and eventually the route through node D will reappear.

# %% [markdown]
# ## 3.  Assignment
# ### Part 1
# From A ping one of C's interfaces. See if you can trick OSPF into failing to route packets momentarily (causing ping to hang) even though there is a path from A to C.
# 1. Briefly describe how you did it?
#
# ### Part 2
# The hello interval and dead interval values can be configured in the ospfd configuration located at /etc/quagga/ospfd.conf. Modify this file on each of the nodes, adding two lines below each interface like this:
# <br> `interface eth1`
# <br> `ip ospf hello-interval 2`
# <br> `ip ospf dead-interval 5`
#
# This changes the hello interval to 2 seconds and the dead  interval to 5 seconds. Change these values on each of the 4 nodes, and then restart the quagga by typing the following command: ```sudo /etc/init.d/ospfd restart```
# Finally enter the router interface by typing: ```vtysh```
#
# Then redo 2.2 and 2.3 to answer the following questions:
#
# 1. From your experience in the main part of the experiment, before you made changes, what is the default value of the dead-interval for this implementation of OSPF?
# 2. After making the above changes, what is different in how OSPF responds to broken links?
# 3. What types of networks would shorter hello-interval and dead interval values be more suited for?
# 4. What is one downside of using shorter hello-intervals and dead-intervals?

# %% [markdown]
# ## Cleanup Resources
# Once you have completed the assignment shut down the slice.

# %%
# Delete Slice
try:
    #To delete the slice change "CHECK" to "True", this is to prevent accidental slice deletion
    CHECK = False
    if (CHECK):
        slice = fablib.get_slice(slice_name)
        slice.delete()
    else:
        print("Change the Boolean to delete slice")
except Exception as e:
    print(f"Fail: {e}")
